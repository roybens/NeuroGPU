# %%
import numpy as np
import struct
import matplotlib.pyplot as plt

# %%
def nrnMread(fileName):
    f = open(fileName, "rb")
    nparam = struct.unpack('i', f.read(4))[0]
    typeFlg = struct.unpack('i', f.read(4))[0]
    return np.fromfile(f,np.double)

# %%
volts = nrnMread("../Data/VHotP0.dat")

# %%
plt.plot(volts[:40000])
