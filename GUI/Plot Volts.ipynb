# %%
tkinter_enabled = False

# %%
if tkinter_enabled:
    from plotVolts import * 
else:
    from plotVolts_noTk import *
    
import os

# %%
init_working_dir()

if tkinter_enabled:
    from plotVolts import base 
else:
    from plotVolts_noTk import base
# Out:
# If you hit enter then you will use default file: pyNeuroGPU_unix/Data/
# choose where simulation output is located

# %%
# base = os.path.join("pyNeuroGPU_unix","Data/")


readOutput(base,'VHotP.dat')
# Out:
# 100000
