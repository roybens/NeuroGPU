# %%
tkinter_enabled = False

# %%
if tkinter_enabled:
    from plotVolts import * 
else:
    from plotVolts_noTk import *
    
import os

# %% [markdown]
# # Initialize Working Directory
# - We will choose a folder that has a .dat file containg voltage traces.

# %%
init_working_dir()
# Out:
# If you hit enter then you will use default file: BBP_TTPC_EXAMPLE/pyNeuroGPU_unix/Data/
# choose where simulation output is located
# chose:  BBP_TTPC_EXAMPLE/pyNeuroGPU_unix/Data/

# %% [markdown]
# # Select Voltages
# - We choose the actual voltage trace we want to plot. In this case we choose the voltage corresponding to stimulation 0.
# - The printed number `31680000` is the total amount of timesteps for all simulated models.
# - In the next step we will just plot one model

# %%
# base = os.path.join("pyNeuroGPU_unix","Data/")

readOutput('VHotP0.dat')
# Out:
# 31680000

# %% [markdown]
# # Select Simulations
# - Now, we will plot a two  simulated models that have different parameters for their channel conductances.
# - We see that different models result in different looking voltage traces.

# %%
plotModel(100)
plotModel(2000)
