# %%
import os
stim_path = './x2stims/'
volt_path = './volts/pdx/'
stims = os.listdir(stim_path)
volts = os.listdir(volt_path)

def cut_stims(stims, volts):
    for stim in stims:
        for volt in volts:
            if stim in volt:
                print('stim:', stim, 'volt:', volt)
                os.remove(stim_path+stim)

def check_missing(stims, volts):
    count = 0
    record = []
    stims = sorted(stims)
    for i in range(len(volts)):
        volts[i] = volts[i][5:]
    volts = sorted(volts)
    
#     print(len(volts))
    
    for i in range(len(volts)):
        print(i)
        if stims[i] != volts[i]:
            print('NOT EQUAL!!!!!!!!!!!!!!!!')
        print(stims[i])
        print(volts[i])
        print('--')
        
        
#     for stim in stims:
#         found = False
#         count += 1
#         for volt in volts:
#             if stim in volt:
#                 found = True
#                 print(count)
#                 if volt in record:
#                     print('REPEAT!!!!!!')
#                 else:
#                     record.append(volt)
#                 print(volt[5:])
#                 print(stim)
#                 print('--')
#         if found is False:
#             print('missing stim:', stim)

# %%
# cut_stims(stims, volts)
check_missing(stims, volts)
# Out:
# 0
# Chirp_m_-0p21_a_0p01_to_0p01_f_0p01_to_0p01.csv
# Chirp_m_-0p21_a_0p01_to_0p01_f_0p01_to_0p01.csv
# --
# 1
# Chirp_m_-0p21_a_0p01_to_0p01_f_0p01_to_0p04.csv
# Chirp_m_-0p21_a_0p01_to_0p01_f_0p01_to_0p04.csv
# --
# 2
# Chirp_m_-0p21_a_0p01_to_0p01_f_0p04_to_0p01.csv
# Chirp_m_-0p21_a_0p01_to_0p01_f_0p04_to_0p01.csv
# --
# 3
# Chirp_m_-0p21_a_0p01_to_0p01_f_0p04_to_0p04.csv
# Chirp_m_-0p21_a_0p01_to_0p01_f_0p04_to_0p04.csv
# --
# 4
# Chirp_m_-0p21_a_0p01_to_0p04_f_0p01_to_0p01.csv
# Chirp_m_-0p21_a_0p01_to_0p04_f_0p01_to_0p01.csv
# --
# 5
# Chirp_m_-0p21_a_0p01_to_0p04_f_0p01_to_0p04.csv
# Chirp_m_-0p21_a_0p01_to_0p04_f_0p01_to_0p04.csv
# --
# 6
# Chirp_m_-0p21_a_0p01_to_0p04_f_0p04_to_0p01.csv
# Chirp_m_-0p21_a_0p01_to_0p04_f_0p04_to_0p01.csv
# --
# 7
# Chirp_m_-0p21_a_0p01_to_0p04_f_0p04_to_0p04.csv
# Chirp_m_-0p21_a_0p01_to_0p04_f_0p04_to_0p04.csv
# --
# 8
# Chirp_m_-0p21_a_0p01_to_0p09_f_0p01_to_0p01.csv
# Chirp_m_-0p21_a_0p01_to_0p09_f_0p01_to_0p01.csv
# --
# 9
# ...
