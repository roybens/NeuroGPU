# %% [markdown]
# # Runtime Analysis cProfile

# %%
import pstats


results_dir = "../python/"
file = 'cprof_out.txt'

p = pstats.Stats(results_dir + file)
p.sort_stats('cumtime').print_stats(1000)
# Out:
# Wed Jul 29 07:16:27 2020    ../python/cprof_out.txt
#
#          10379745 function calls (6482194 primitive calls) in 127.787 seconds
#
#    Ordered by: cumulative time
#    List reduced from 6260 to 1000 due to restriction <1000>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    1310/1    0.027    0.000  127.788  127.788 {built-in method builtins.exec}
#         1    0.002    0.002  127.788  127.788 optimize_parameters_genetic_alg.py:1(<module>)
#         1    0.000    0.000  126.374  126.374 optimize_parameters_genetic_alg.py:94(main)
#         1    0.000    0.000  126.361  126.361 /global/homes/z/zladd/.conda/envs/.env/lib/python3.6/site-packages/bluepyopt/deapext/optimisations.py:256(run)
#         1    0.000    0.000  126.346  126.346 /global/homes/z/zladd/.conda/envs/.env/lib/python3.6/site-packages/bluepyopt/deapext/algorithms.py:72(eaAlphaMuPlusLambdaCheckpoint)
# ...
